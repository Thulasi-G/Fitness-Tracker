# %%
import pandas as pd

# %%
df=pd.read_csv("/content/fitness_tracker.csv")
df
# Out:
#       User_ID     Name   Age  Gender    Steps  Calories_Burned  \
# 0     FIT1000   Suresh   NaN  Female  15257.0            300.0
# 1     FIT1001    Priya  30.0    Male   1570.0            119.0
# 2     FIT1002     Arun  49.0    Male  15594.0            206.0
# 3     FIT1003   Vikram  39.0  Female   4085.0              NaN
# 4     FIT1004    Divya  23.0    Male  14407.0            969.0
# ...       ...      ...   ...     ...      ...              ...
# 4996  FIT5996     Arun  33.0    Male  13224.0            357.0
# 4997  FIT5997  Lakshmi  34.0    Male  12493.0              NaN
# 4998  FIT5998    Kavya  48.0  Female   7945.0            109.0
# 4999  FIT5999      NaN  24.0  Female  13793.0            710.0
# 5000  FIT6000      NaN  23.0    Male  12654.0            720.0
#
#       Workout_Duration_Min        Date  Heart_Rate  Sleep_Hours
# 0                     97.0  01-01-2022         NaN          7.8
# 1                      NaN  02-01-2022       179.0          3.8
# ...

# %%
df.head()
# Out:
#    User_ID    Name   Age  Gender    Steps  Calories_Burned  \
# 0  FIT1000  Suresh   NaN  Female  15257.0            300.0
# 1  FIT1001   Priya  30.0    Male   1570.0            119.0
# 2  FIT1002    Arun  49.0    Male  15594.0            206.0
# 3  FIT1003  Vikram  39.0  Female   4085.0              NaN
# 4  FIT1004   Divya  23.0    Male  14407.0            969.0
#
#    Workout_Duration_Min        Date  Heart_Rate  Sleep_Hours
# 0                  97.0  01-01-2022         NaN          7.8
# 1                   NaN  02-01-2022       179.0          3.8
# 2                  33.0  03-01-2022       133.0          4.0
# 3                 117.0  04-01-2022        95.0          NaN
# 4                  56.0  05-01-2022        84.0          NaN

# %%
df.tail()
# Out:
#       User_ID     Name   Age  Gender    Steps  Calories_Burned  \
# 4996  FIT5996     Arun  33.0    Male  13224.0            357.0
# 4997  FIT5997  Lakshmi  34.0    Male  12493.0              NaN
# 4998  FIT5998    Kavya  48.0  Female   7945.0            109.0
# 4999  FIT5999      NaN  24.0  Female  13793.0            710.0
# 5000  FIT6000      NaN  23.0    Male  12654.0            720.0
#
#       Workout_Duration_Min        Date  Heart_Rate  Sleep_Hours
# 4996                  62.0         NaN        94.0          3.2
# 4997                  18.0  07-09-2035       120.0          4.2
# 4998                  40.0  08-09-2035        75.0          8.5
# 4999                  65.0  09-09-2035       131.0         10.0
# 5000                  75.0  04-09-2035        43.0          NaN

# %%
df.shape
# Out:
# (5001, 10)

# %%
df.columns
# Out:
# Index(['User_ID', 'Name', 'Age', 'Gender', 'Steps', 'Calories_Burned',
#        'Workout_Duration_Min', 'Date', 'Heart_Rate', 'Sleep_Hours'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                  object
# Name                     object
# Age                     float64
# Gender                   object
# Steps                   float64
# Calories_Burned         float64
# Workout_Duration_Min    float64
# Date                     object
# Heart_Rate              float64
# Sleep_Hours             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   User_ID               4501 non-null   object
#  1   Name                  4500 non-null   object
#  2   Age                   4501 non-null   float64
#  3   Gender                4501 non-null   object
#  4   Steps                 4501 non-null   float64
#  5   Calories_Burned       4501 non-null   float64
#  6   Workout_Duration_Min  4501 non-null   float64
#  7   Date                  4501 non-null   object
#  8   Heart_Rate            4501 non-null   float64
#  9   Sleep_Hours           4500 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#                Age         Steps  Calories_Burned  Workout_Duration_Min  \
# count  4501.000000   4501.000000      4501.000000           4501.000000
# mean     41.036214  10443.373028       549.762275             64.829371
# std      13.388395   5458.168131       258.651468             31.816694
# min      18.000000   1002.000000       100.000000             10.000000
# 25%      30.000000   5719.000000       325.000000             37.000000
# 50%      41.000000  10417.000000       551.000000             65.000000
# 75%      52.000000  15246.000000       773.000000             92.000000
# max      64.000000  19988.000000       999.000000            119.000000
#
#         Heart_Rate  Sleep_Hours
# count  4501.000000  4500.000000
# mean    119.264164     6.512044
# std      34.948810     2.048222
# min      43.000000     3.000000
# 25%      89.000000     4.700000
# 50%     120.000000     6.500000
# 75%     150.000000     8.300000
# max     179.000000    10.000000

# %%
print( df["User_ID"].isnull().sum())
# Out:
# 500

# %%
df["User_ID"].fillna(method="ffill", inplace=True)
df["User_ID"].fillna(method="bfill", inplace=True)
df
# Out:
# /tmp/ipython-input-823088267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["User_ID"].fillna(method="ffill", inplace=True)
# /tmp/ipython-input-823088267.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["User_ID"].fillna(method="ffill", inplace=True)
# ...

# %%
df["User_ID"].fillna(0, inplace=True)
df
# Out:
# /tmp/ipython-input-4044742473.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["User_ID"].fillna(0, inplace=True)
#       User_ID     Name  Age  Gender  Steps  Calories_Burned  \
# 0     FIT1000   Suresh   41  Female  15257              300
# 12    FIT1031  Karthik   40  Female  15087              731
# 24    FIT1059   Ramesh   58    Male  13877              551
# 36    FIT1090   Ramesh   46  Female  11087              438
# 55    FIT1151    Divya   59  Female   4513              551
# ...

# %%
print(df["User_ID"].isnull().sum())
# Out:
# 0

# %%
df["Name"]=df["Name"].str.strip()
df
# Out:
#       User_ID     Name  Age  Gender  Steps  Calories_Burned  \
# 0     FIT1000   Suresh   41  Female  15257              300
# 12    FIT1031  Karthik   40  Female  15087              731
# 24    FIT1059   Ramesh   58    Male  13877              551
# 36    FIT1090   Ramesh   46  Female  11087              438
# 55    FIT1151    Divya   59  Female   4513              551
# ...       ...      ...  ...     ...    ...              ...
# 1719  FIT5849   Ramesh   30  Female  12603              232
# 1728  FIT5879    Kavya   41    Male  15427              822
# 1739  FIT5910  Unknown   59  Female  10417              918
# 1750  FIT5940  Karthik   32  Female   6712              354
# 1759  FIT5971  Lakshmi   48  Female   5711              878
#
#       Workout_Duration_Min       Date  Heart_Rate  Sleep_Hours         City
# 0                       97 2022-01-01         121          7.8     New York
# 12                      95 2022-01-02         168          7.9  Los Angeles
# ...

# %%
df["Name"]=df["Name"].str.title()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3235548023.py in <cell line: 0>()
# ----> 1 df["Name"]=df["Name"].str.title()
#
# NameError: name 'df' is not defined

# %%
df["Name"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipython-input-2160184949.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name"].fillna("Unknown",inplace=True)

# %%
print(df["Name"])
# Out:
# 0        Suresh
# 1         Priya
# 2          Arun
# 3        Vikram
# 4         Divya
#          ...
# 4996       Arun
# 4997    Lakshmi
# 4998      Kavya
# 4999    Unknown
# 5000    Unknown
# Name: Name, Length: 5001, dtype: object

# %%
print( df["Name"].isnull().sum())
# Out:
# 0

# %%
df["Age"]=df["Age"].astype(float)

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)
# Out:
# /tmp/ipython-input-860536840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df.loc[(df["Age"]<0),"Age"]=df["Age"].median()

# %%
df.loc[(df["Age"]>120),"Age"]=df["Age"].median()

# %%
df["Age"] = df["Age"].astype(int)

# %%
print(df["Age"].describe())
# Out:
# count    5001.000000
# mean       41.032593
# std        12.701352
# min        18.000000
# 25%        31.000000
# 50%        41.000000
# 75%        51.000000
# max        64.000000
# Name: Age, dtype: float64

# %%
print( df["Age"].isnull().sum())
# Out:
# 0

# %%
df["Gender"]=df["Gender"].astype(str)

# %%
df["Gender"]=df["Gender"].str.strip().str.capitalize()

# %%
df["Gender"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipython-input-4079419841.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Gender"].fillna("Unknown",inplace=True)

# %%
print( df["Gender"].isnull().sum())
# Out:
# 0

# %%
df["Steps"] = df["Steps"].astype(float)

# %%
df["Steps"].fillna(df["Steps"].median(), inplace=True)
# Out:
# /tmp/ipython-input-3160786177.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Steps"].fillna(df["Steps"].median(), inplace=True)

# %%
df.loc[(df["Steps"] < 0),"Steps"]= df["Steps"].median()

# %%
df.loc[(df["Steps"] > 1000000),"Steps"]= df["Steps"].median()

# %%
df["Steps"] = df["Steps"].astype(int)

# %%
print(df["Steps"].describe())
# Out:
# count     5001.000000
# mean     10440.736253
# std       5178.078989
# min       1002.000000
# 25%       6256.000000
# 50%      10417.000000
# 75%      14555.000000
# max      19988.000000
# Name: Steps, dtype: float64

# %%
print( df["Steps"].isnull().sum())
# Out:
# 0

# %%
df["Calories_Burned"] = df["Calories_Burned"].astype(float)

# %%
df["Calories_Burned"].fillna(df["Calories_Burned"].median(), inplace=True)
# Out:
# /tmp/ipython-input-2391815721.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories_Burned"].fillna(df["Calories_Burned"].median(), inplace=True)

# %%
df.loc[(df["Calories_Burned"] < 0) , "Calories_Burned"]=df["Calories_Burned"].median()

# %%
df.loc[(df["Calories_Burned"] > 10000) , "Calories_Burned"]=df["Calories_Burned"].median()

# %%
df["Calories_Burned"] = df["Calories_Burned"].astype(int)

# %%
print(df["Calories_Burned"].describe())
# Out:
# count    5001.000000
# mean      549.886023
# std       245.378609
# min       100.000000
# 25%       349.000000
# 50%       551.000000
# 75%       750.000000
# max       999.000000
# Name: Calories_Burned, dtype: float64

# %%
print( df["Calories_Burned"].isnull().sum())
# Out:
# 0

# %%
df["Workout_Duration_Min"]=df["Workout_Duration_Min"].astype(float)

# %%
df["Workout_Duration_Min"].fillna(df["Workout_Duration_Min"].median(), inplace=True)
# Out:
# /tmp/ipython-input-2295023151.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Workout_Duration_Min"].fillna(df["Workout_Duration_Min"].median(), inplace=True)

# %%
df.loc[(df["Workout_Duration_Min"] < 0), "Workout_Duration_Min"]= df["Workout_Duration_Min"].median()

# %%
df.loc[(df["Workout_Duration_Min"] > 1440), "Workout_Duration_Min"]= df["Workout_Duration_Min"].median()

# %%
df["Workout_Duration_Min"] = df["Workout_Duration_Min"].astype(int)

# %%
print(df["Workout_Duration_Min"].describe())
# Out:
# count    5001.000000
# mean       64.846431
# std        30.184009
# min        10.000000
# 25%        40.000000
# 50%        65.000000
# 75%        89.000000
# max       119.000000
# Name: Workout_Duration_Min, dtype: float64

# %%
print( df["Workout_Duration_Min"].isnull().sum())
# Out:
# 0

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# %%
df.dropna(subset=["Date"], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.sort_values(by="Date", inplace=True)

# %%
print(df["Date"].head())
# Out:
# 0    2022-01-01
# 12   2022-01-02
# 24   2022-01-03
# 36   2022-01-04
# 55   2022-01-06
# Name: Date, dtype: datetime64[ns]

# %%
print( df["Date"].isnull().sum())
# Out:
# 0

# %%
df["Heart_Rate"] = df["Heart_Rate"].astype(float)

# %%
df["Heart_Rate"].fillna(df["Heart_Rate"].median(), inplace=True)
# Out:
# /tmp/ipython-input-1642609296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Heart_Rate"].fillna(df["Heart_Rate"].median(), inplace=True)

# %%
df.loc[(df["Heart_Rate"] < 40) | (df["Heart_Rate"] > 220), "Heart_Rate"] = df["Heart_Rate"].median()

# %%
df["Heart_Rate"] = df["Heart_Rate"].astype(int)

# %%
print(df["Heart_Rate"].describe())
# Out:
# count    1768.000000
# mean      119.978507
# std        33.880121
# min        43.000000
# 25%        91.000000
# 50%       121.000000
# 75%       148.000000
# max       179.000000
# Name: Heart_Rate, dtype: float64

# %%
print( df["Heart_Rate"].isnull().sum())
# Out:
# 0

# %%
df["Sleep_Hours"] = df["Sleep_Hours"].astype(float)

# %%
df["Sleep_Hours"].fillna(df["Sleep_Hours"].median(), inplace=True)
# Out:
# /tmp/ipython-input-3620286179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sleep_Hours"].fillna(df["Sleep_Hours"].median(), inplace=True)

# %%
df.loc[(df["Sleep_Hours"] < 0) | (df["Sleep_Hours"] > 24), "Sleep_Hours"] = df["Sleep_Hours"].median()

# %%
df["Sleep_Hours"] = df["Sleep_Hours"].round(1)

# %%
print(df["Sleep_Hours"].describe())
# Out:
# count    1768.000000
# mean        6.629808
# std         1.915481
# min         3.000000
# 25%         5.100000
# 50%         6.700000
# 75%         8.200000
# max        10.000000
# Name: Sleep_Hours, dtype: float64

# %%
print( df["Sleep_Hours"].isnull().sum())
# Out:
# 0

# %%
cities = ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"]

# %%
df["City"] = [cities[i % len(cities)] for i in range(len(df))]

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv("/content/fitness_tracker.csv", index=False)

# %%
print( df["City"].isnull().sum())
# Out:
# 0

# %%
df
# Out:
#       User_ID     Name  Age  Gender  Steps  Calories_Burned  \
# 0     FIT1000   Suresh   41  Female  15257              300
# 12    FIT1031  Karthik   40  Female  15087              731
# 24    FIT1059   Ramesh   58    Male  13877              551
# 36    FIT1090   Ramesh   46  Female  11087              438
# 55    FIT1151    Divya   59  Female   4513              551
# ...       ...      ...  ...     ...    ...              ...
# 1719  FIT5849   Ramesh   30  Female  12603              232
# 1728  FIT5879    Kavya   41    Male  15427              822
# 1739  FIT5910  Unknown   59  Female  10417              918
# 1750  FIT5940  Karthik   32  Female   6712              354
# 1759  FIT5971  Lakshmi   48  Female   5711              878
#
#       Workout_Duration_Min       Date  Heart_Rate  Sleep_Hours         City
# 0                       97 2022-01-01         121          7.8     New York
# 12                      95 2022-01-02         168          7.9  Los Angeles
# ...

# %%
df.to_excel("cleaned_file.xlsx", index=False)


from google.colab import files
files.download("cleaned_file.xlsx")
